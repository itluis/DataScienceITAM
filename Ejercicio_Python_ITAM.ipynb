# %% [markdown]
# ## EJERCICIO Python ITAM-Citibanamex
# @Luis Enrique Martínez González
# @Aaron Soto Vega
# @Omar Hernandez García
#
# 1. Importa con la librería de pandas, como csv, los datos que vienen aquí:
#
#     - https://s3-ap-southeast-1.amazonaws.com/av-datahack-datacamp/train.csv y llámalo train.set
#
#     - https://s3-ap-southeast-1.amazonaws.com/av-datahack-datacamp/test.csv y llámalo test.set

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train=pd.read_csv('C:/Users/luise/Documents/ITAM/DataScience/Datasets/train.csv')
test=pd.read_csv('C:/Users/luise/Documents/ITAM/DataScience/Datasets/test.csv')

# %%
train.head(5)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
test.head(5)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %% [markdown]
# 2. Revisa este sitio para que entiendas el reto.Busca la documentación que viene sobre el dataset para llenar la misma tabla que llenaste para R, en donde venga la descripción, el tipo de variable, los rangos.

# %%
from prettytable import PrettyTable

# %%
traintab = PrettyTable()
traintab.field_names = ["Variable Name", "Description", "Variable Type", "Sample Value"]
traintab.add_row(["Loan_ID", "Loan unique key", "Categorical", "LP001002"])
traintab.add_row(["Gender", "customer gender", "Categorical", "Male"])
traintab.add_row(["Married", "married status", "Categorical", "No"])
traintab.add_row(["Dependents", "# economic realtives", "Numerical", "2"])
traintab.add_row(["Education", "education level", "Categorical", "Graduate"])
traintab.add_row(["Self_Employed", "Employment flag", "Categorical", "Yes"])
traintab.add_row(["ApplicantIncome", "income amount", "Numerical", "$5,849"])
traintab.add_row(["CoApplicantIncome", "relative income amount", "Numerical", "$1,508"])
traintab.add_row(["Loan_amount", "amount borrowed", "Numerical", "$128"])
traintab.add_row(["Loan_amount_term", "loan period", "Numerical", "360"])
traintab.add_row(["Credit_history", "credit flag", "Categorical", "0"])
traintab.add_row(["Property_Area", "customer living area", "Categorical", "Urban"])
traintab.add_row(["Loan_Status", "Loan Flag", "Categorical", "Y"])

print("Loan Variables Description:")
print(traintab)
# Out:
# Loan Variables Description:
# +-------------------+------------------------+---------------+--------------+
# |   Variable Name   |      Description       | Variable Type | Sample Value |
# +-------------------+------------------------+---------------+--------------+
# |      Loan_ID      |    Loan unique key     |  Categorical  |   LP001002   |
# |       Gender      |    customer gender     |  Categorical  |     Male     |
# |      Married      |     married status     |  Categorical  |      No      |
# |     Dependents    |  # economic realtives  |   Numerical   |      2       |
# |     Education     |    education level     |  Categorical  |   Graduate   |
# |   Self_Employed   |    Employment flag     |  Categorical  |     Yes      |
# |  ApplicantIncome  |     income amount      |   Numerical   |    $5,849    |
# | CoApplicantIncome | relative income amount |   Numerical   |    $1,508    |
# |    Loan_amount    |    amount borrowed     |   Numerical   |     $128     |
# ...

# %% [markdown]
# 3. ¿Cuántas observaciones se tienen en cada dataset? ¿Cuántas columnas (puedes usar `dataframe.columns`)? ¿Cuáles son los primeros 5 registros?

# %%
print("Statistical Summary for Train dataset:")
train.describe()
# Out:
# Statistical Summary for Train dataset:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
print("Observations for train dataset:")
train.shape
# Out:
# Observations for train dataset:
# (614, 13)

# %%
print("Statistical Summary for test dataset:")
test.describe()
# Out:
# Statistical Summary for test dataset:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
print("Observations for test dataset:")
test.shape
# Out:
# Observations for test dataset:
# (367, 12)

# %% [markdown]
# 4. Observa cuántos NULLs tienes por columna y por fila (usa la función que vimos para hacerlo para todas las columnas/filas de una vez). Elimina las filas en donde haya valores nulos.

# %%
train.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
test.isna().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
traindf = train.dropna()
print(traindf)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 12   LP001028    Male     Yes          2      Graduate            No
# 13   LP001029    Male      No          0      Graduate            No
# 14   LP001030    Male     Yes          2      Graduate            No
# ...

# %%
testdf = test.dropna()
print(testdf)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001015    Male     Yes          0      Graduate            No
# 1    LP001022    Male     Yes          1      Graduate            No
# 2    LP001031    Male     Yes          2      Graduate            No
# 4    LP001051    Male      No          0  Not Graduate            No
# 5    LP001054    Male     Yes          0  Not Graduate           Yes
# 6    LP001055  Female      No          1  Not Graduate            No
# 7    LP001056    Male     Yes          2  Not Graduate            No
# 9    LP001067    Male      No          0  Not Graduate            No
# 10   LP001078    Male      No          0  Not Graduate            No
# 14   LP001096  Female      No          0      Graduate            No
# 15   LP001099    Male      No          1      Graduate            No
# 16   LP001105    Male     Yes          2      Graduate            No
# 17   LP001107    Male     Yes         3+      Graduate            No
# ...

# %% [markdown]
# 5. Recodifica a 0-1 las variables categóricas que estén siendo tratadas como strings. Usa la función `replace` que vimos, con un diccionario para hacer esto.

# %%
train.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
test.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome      int64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# dtype: object

# %%
traindf= traindf.replace({'Male':0, 'Female': 1, 'Yes':1, 'No':0, 'Graduate':1, 'Not Graduate':0, 'Y':1, "N":0 })
print(traindf)
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 1    LP001003       0        1          1          1              0
# 2    LP001005       0        1          0          1              1
# 3    LP001006       0        1          0          0              0
# 4    LP001008       0        0          0          1              0
# 5    LP001011       0        1          2          1              1
# 6    LP001013       0        1          0          0              0
# 7    LP001014       0        1         3+          1              0
# 8    LP001018       0        1          2          1              0
# 9    LP001020       0        1          1          1              0
# 10   LP001024       0        1          2          1              0
# 12   LP001028       0        1          2          1              0
# 13   LP001029       0        0          0          1              0
# 14   LP001030       0        1          2          1              0
# ...

# %%
testdf= testdf.replace({'Male':0, 'Female': 1, 'Yes':1, 'No':0, 'Graduate':1, 'Not Graduate':0, 'Y':1, "N":0 })
print(testdf)
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001015       0        1          0          1              0
# 1    LP001022       0        1          1          1              0
# 2    LP001031       0        1          2          1              0
# 4    LP001051       0        0          0          0              0
# 5    LP001054       0        1          0          0              1
# 6    LP001055       1        0          1          0              0
# 7    LP001056       0        1          2          0              0
# 9    LP001067       0        0          0          0              0
# 10   LP001078       0        0          0          0              0
# 14   LP001096       1        0          0          1              0
# 15   LP001099       0        0          1          1              0
# 16   LP001105       0        1          2          1              0
# 17   LP001107       0        1         3+          1              0
# ...

# %% [markdown]
# 6. Da un resumen de la media, la mediana, desviación estándar, mínimo, máximo de las variables. Adicionalmente usa `df[col_name].value_counts()` para saber cuántas observaciones se tienen para las variables categóricas.

# %%
print("Statistical Summary for Train dataset:")
train.describe()
# Out:
# Statistical Summary for Train dataset:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
print("Statistical Summary for Test dataset:")
test.describe()
# Out:
# Statistical Summary for Test dataset:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
train['Gender'].value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
train['Education'].value_counts()
# Out:
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64

# %%
train['Self_Employed'].value_counts()
# Out:
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64

# %%
train['Loan_Status'].value_counts()
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64

# %%
train['Married'].value_counts()
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64

# %%
train['Property_Area'].value_counts()
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64

# %% [markdown]
# 7. Para las variables categóricas, usa una `crosstab` para saber si se les da más créditos a las mujeres que a los hombres.  Usa otra `crosstab` para saber si el hecho de tener historial crediticio hace que sea más fácil que te aprueben un crédito. ¿Cuáles son tus conclusiones?
#     **BONUS:** Investiga cómo poner porcentajes en estas tabla en vez de números.

# %%
pd.crosstab(train.Gender,train.Loan_Status)
# Out:
# Loan_Status    N    Y
# Gender
# Female        37   75
# Male         150  339

# %%
pd.crosstab(train.Gender,train.Loan_Status,normalize='index')
# Out:
# Loan_Status         N         Y
# Gender
# Female       0.330357  0.669643
# Male         0.306748  0.693252

# %%
pd.crosstab(train.Credit_History, train.Loan_Status)
# Out:
# Loan_Status      N    Y
# Credit_History
# 0.0             82    7
# 1.0             97  378

# %%
pd.crosstab(train.Credit_History, train.Loan_Status,normalize='index')
# Out:
# Loan_Status            N         Y
# Credit_History
# 0.0             0.921348  0.078652
# 1.0             0.204211  0.795789

# %% [markdown]
# Observación: El género no es una variable determinante para otorgar un crédito (H 69% vs M 66%), sin embargo el contar con historial crediticio es crítico con una probabilidad del 79% de aceptación del crédito.

# %% [markdown]
# 8. Haz un histograma para el ingreso de la persona y otro para la cantidad prestada. ¿Qué observas?

# %%
plt.hist(train.ApplicantIncome)
plt.title("Applicant Income")
plt.xlabel("Value")
plt.ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %% [markdown]
# Observación: La concentración de datos muestra una asimetría,la mayoría de los clientes tiene un ingreso menor a los $10,000. Existen algunos clientes atípicps con sueldos más elevados.

# %%
plt.hist(train.LoanAmount.dropna())
plt.title("Loan Amount")
plt.xlabel("Value")
plt.ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %% [markdown]
# Observación: La mayor concentración de prestámos se otorga por un monto entre un rango de $90-$200

# %% [markdown]
# 9. Haz un boxplot para la cantidad del préstamo según el historial crediticio de la persona. ¿Hay diferencias en la cantidad prestada dependiendo si tiene historial o no? Repite el mismo boxplot pero ahora según el sexo. ¿Hay diferencias?

# %%
data= [train[train.Credit_History==1.0].LoanAmount.dropna(),train[train.Credit_History==0.0].LoanAmount.dropna()]
fig,history=plt.subplots()
history.boxplot(data)
plt.title("Loan Amount by Credit History")
plt.ylabel("Loan Amount")
plt.xlabel(["1=Yes","2=No"])
plt.show()

# %% [markdown]
# Observación: se puede ver que la distribución de las cantidades de préstamos para los que tienen y no historial crediticio es muy similar. Sin embargo, no hace sentido ya que si un cliente no cuenta con historial el préstamos otorgado debería ser por un monto menor.

# %%
data= [train[train.Gender=='Male'].LoanAmount.dropna(),train[train.Gender=='Female'].LoanAmount.dropna()]
fig,gender=plt.subplots()
gender.boxplot(data)
plt.title("Loan Amount by gender distributions")
plt.ylabel("Loan Amount")
plt.xlabel(["1=Male","2=Female"])
plt.show()

# %% [markdown]
# Observación: Se interpreta que el cliente al ser del género masculino tiene mayor posibilidad de recibir un préstamos en un rango de monto mayor que en el caso de una mujer.
